# %%
x = 5
x
# Out:
# 5

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/karim/Workspace/github.com/me/iko/datasets/data.csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
for index, row in df.iterrows():
    print(row[1])
# Out:
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# B
# B
# B
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# B
# M
# M
# M
# M
# M
# M
# M
# M
# B
# M
# B
# B
# B
# B
# B
# M
# M
# B
# M
# M
# B
# B
# B
# B
# M
# B
# M
# M
# B
# B
# B
# B
# M
# B
# M
# M
# B
# M
# B
# M
# M
# B
# B
# B
# M
# M
# B
# M
# M
# M
# B
# B
# B
# M
# B
# B
# M
# M
# B
# B
# B
# M
# M
# B
# B
# B
# B
# M
# B
# B
# M
# B
# B
# B
# B
# B
# B
# B
# B
# M
# M
# M
# B
# M
# M
# B
# B
# B
# M
# M
# B
# M
# B
# M
# M
# B
# M
# M
# B
# B
# M
# B
# B
# M
# B
# B
# B
# B
# M
# B
# B
# B
# B
# B
# B
# B
# B
# B
# M
# B
# B
# B
# B
# M
# M
# B
# M
# B
# B
# M
# M
# B
# B
# M
# M
# B
# B
# B
# B
# M
# B
# B
# M
# M
# M
# B
# M
# B
# M
# B
# B
# B
# M
# B
# B
# M
# M
# B
# M
# M
# M
# M
# B
# M
# M
# M
# B
# M
# B
# M
# B
# B
# M
# B
# M
# M
# M
# M
# B
# B
# M
# M
# B
# B
# B
# M
# B
# B
# B
# B
# B
# M
# M
# B
# B
# M
# B
# B
# M
# M
# B
# M
# B
# B
# B
# B
# M
# B
# B
# B
# B
# B
# ...

# %%
# Out:
# M 17.99 10.38 122.8
# M 20.57 17.77 132.9
# M 19.69 21.25 130.0
# M 11.42 20.38 77.58
# M 20.29 14.34 135.1
# M 12.45 15.7 82.57
# M 18.25 19.98 119.6
# M 13.71 20.83 90.2
# M 13.0 21.82 87.5
# M 12.46 24.04 83.97
# M 16.02 23.24 102.7
# M 15.78 17.89 103.6
# M 19.17 24.8 132.4
# M 15.85 23.95 103.7
# M 13.73 22.61 93.6
# M 14.54 27.54 96.73
# M 14.68 20.13 94.74
# M 16.13 20.68 108.1
# M 19.81 22.15 130.0
# B 13.54 14.36 87.46
# B 13.08 15.71 85.63
# B 9.504 12.44 60.34
# M 15.34 14.26 102.5
# M 21.16 23.04 137.2
# M 16.65 21.38 110.0
# M 17.14 16.4 116.0
# M 14.58 21.53 97.41
# M 18.61 20.25 122.1
# M 15.3 25.27 102.4
# M 17.57 15.05 115.0
# M 18.63 25.11 124.8
# M 11.84 18.7 77.93
# M 17.02 23.98 112.8
# M 19.27 26.47 127.9
# M 16.13 17.88 107.0
# M 16.74 21.59 110.1
# M 14.25 21.72 93.63
# B 13.03 18.42 82.61
# M 14.99 25.2 95.54
# M 13.48 20.82 88.4
# M 13.44 21.58 86.18
# M 10.95 21.35 71.9
# M 19.07 24.81 128.3
# M 13.28 20.28 87.32
# M 13.17 21.81 85.42
# M 18.65 17.6 123.7
# ...

# %%
for l in df.loc:
    x = l.tolist()
    print(x)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-21-8c16337cb2ef> in <module>
# ----> 1 for l in df.loc:
#       2     x = l.tolist()
#       3     print(x)
#
# ~/Workspace/github.com/me/iko/venv/lib/python3.7/site-packages/pandas/core/indexing.py in __iter__(self)
#     101
#     102     def __iter__(self):
# --> 103         raise NotImplementedError('ix is not iterable')
#     104
#     105     def __getitem__(self, key):
#
# NotImplementedError: ix is not iterable

# %%
OrdredDict(sorted(x, ))

# %%
from collections import OrderedDict
from itertools import islice

sim_matrix = {1: 5.3, 2: 6.3, 3: 3.6}

o_d = OrderedDict(sorted(sim_matrix.items(), key=(lambda x: x[1]))).items()

#dict(o_d)
aa = islice(o_d, 2)

dict(aa)
# Out:
# {3: 3.6, 1: 5.3}

# %%
from random import sample

class Test:
    def __init__(self):
        id = 5


s = [(5,4), Test(), 3, 9, 8, 11]

x = sample(s, 3)

x
# Out:
# [8, 11, (5, 4)]
